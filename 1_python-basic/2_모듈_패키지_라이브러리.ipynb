# %% [markdown]
# # Module

# %%
import calc as cc  # 권장

# from calc import add, sub, mul, div
# from calc import * # 비권장

print(f"add : {cc.add(1,3)}")
print(f"sub : {cc.sub(19,5)}")
print(f"mul : {cc.mul(6,3)}")
print(f"div : {cc.div(10,5)}")

# %%
# Random Module
import random

print(f"random 1~10 : {random.randint(1,10)}")
print(f"random 1~20 by 2step : {random.randrange(0,20,2)}")

random.randrange(1,20,2)

# %%
# Datetime Module
import datetime as dt

print(f"datetime.now() : {dt.datetime.now()}")

# %%
# OS Module
import os

print(f"getcwd : {os.getenv}")

# %%
# System Module
import sys

print(f"version : {sys.version}")
print(f"api version : {sys.api_version}")

# %%
# Time Module
import time

for i in range(20):
    print(f"progress...[{i}]")
    time.sleep(1)

# %% [markdown]
# # Library
# # pip install

# %%
import requests

requests.get("http://www.google.com")

# %%
import pandas as pd

# 샘플 데이터 생성

data = {
    '이름': ['김철수', '이영희', '박민수', '정수진', '최영호', '한미래', '윤지원'],
    '나이': [25, 28, 22, 31, 27, 24, 29],
    '점수': [85, 92, 78, 95, 88, 73, 91]
}

student_data = {
    "name": ["Kim", "Lee", "Park", "Choi"],
    "age": [20, 22, 21, 23],
    "score": [85, 92, 78, 95]
}

# # DataFrame 생성
# students = pd.DataFrame(student_data)
dt = pd.DataFrame(data)


# print("=== 전체 데이터 ===")
# print(students)

# print("\n=== 상위 2개 데이터 ===")
# print(students.head(2))

# print("\n=== 점수가 90점 이상인 학생 ===")
# high_score_students = students[students["score"] >= 90]
# print(high_score_students)

# # 새로운 컬럼 추가
# students["result"] = students["score"] >= 80

# print("\n=== 합격 여부 추가 ===")
# print(students)

# print("\n=== 평균 점수 ===")
# print(students["score"].mean())

# print("\n=== 최고 점수 ===")
# print(students["score"].max())

# print("\n=== 기본 통계 ===")
# print(students.describe())

print("나이속성의 평균")
print(f"{int(dt["나이"].mean())}")

print("\ndescribe")
print(dt.describe)

# %% [markdown]
# # 모듈 정의하기
#
# 1. calc.py 모듈 만들기
# 2. 모듈내에 함수 정의 - add()

# %%
# 모듈 가져오기

# import module_name as alias
# from module_name import fun1, fun2
# from module_name import *

# %%
# 모듈 단독으로 실행

#if __name__ == '__main__':
    #execute
