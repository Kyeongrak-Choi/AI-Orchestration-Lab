# %%
# 한줄주석

# 변수 선언
name = 'krchoi'

# 나이 입력받기
age = int(input(" please enter your age : "))

# 결과출력
print(f"name : {name}, age : {age}")
# Out:
# 이름 : Alice, 나이 : 31

# %%
# 여러줄 주석
# 이 코드는 사용자의 이름과 나이를 입력 받아
# 화면에 출력하는 프로그램이다.
# Python에서 input()을 이용하여 사용자 입력을 받을 수 있다.

# %%
# 문자열 삼중 따옴표 사용
'''
이 프로그램은 사용자의 정보를 입력 받아 출력하는 기능을 한다.
사용자가 입력한 이름과 나이를 출력하는 간단한 예제이다.
'''
# Out:
# '\n이 프로그램은 사용자의 정보를 입력 받아 출력하는 기능을 한다.\n사용자가 입력한 이름과 나이를 출력하는 간단한 예제이다.\n'
