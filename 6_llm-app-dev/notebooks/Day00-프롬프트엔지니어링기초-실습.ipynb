# %% [markdown]
# # 01. 프롬프트 엔지니어링 실습
#
# ---
#
# ## 학습 목표
#
# LLM의 출력 품질을 높이는 **핵심 프롬프트 기법 6가지**를 실습합니다.
# 같은 질문에 다른 기법을 적용해 결과 차이를 직접 확인합니다.
#
# ## 다루는 기법
#
# | 기법 | 핵심 아이디어 | 언제 쓰나? |
# |---|---|---|
# | **Zero-shot** | 예시 없이 바로 질문 | 간단한 일반 질문 |
# | **Few-shot** | 예시(샷)를 프롬프트에 포함 | 특정 형식·스타일 유도 |
# | **Chain-of-Thought** | 단계별 추론 유도 | 복잡한 분석·판단 |
# | **역할 프롬프트** | LLM에게 페르소나 부여 | 전문 도메인 답변 |
# | **구조화된 출력** | 특정 형식(JSON 등) 강제 | 파싱이 필요한 경우 |
# | **프롬프트 템플릿** | 변수로 재사용 가능한 프롬프트 | 반복 작업 자동화 |
#
# ## 흐름
#
# ```
# 기법 학습 → 코드 실습 → 같은 질문으로 비교 실험 → 핵심 정리
# ```

# %%
from dotenv import load_dotenv
load_dotenv(override=True, dotenv_path="../.env")

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

import json

#LLM 초기화
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

print("준비 완료")
print("실습에 사용할 공통 질문: '재택근무 전면 도입, 찬성해야 할까요?'")
# Out:
# 준비 완료
# 실습에 사용할 공통 질문: '재택근무 전면 도입, 찬성해야 할까요?'

# %% [markdown]
# ---
#
# ## 1. Zero-shot Prompting
#
# **예시 없이** 바로 질문하는 가장 기본적인 방식입니다.
# LLM이 사전 학습 지식만으로 답변합니다.
#
# ```
# 사용자: [질문]
# LLM:   [답변]
# ```

# %%
# ── Zero-shot: 예시 없이 바로 질문 ────────────────────────────
zero_shot_prompt = ChatPromptTemplate.from_messages([
    ("human", "{question}")
])

# 체인 생성 및 실행
chain = zero_shot_prompt | llm | StrOutputParser()
result = chain.invoke({"question": "재택근무 전면 도입, 찬성해야 할까요?"})
# Prompt | LLM | OutputParser 구조

print("=== Zero-shot 결과 ===")
print(result)
# Out:
# === Zero-shot 결과 ===
# 재택근무의 전면 도입에 대한 찬반 의견은 여러 가지 측면에서 고려할 수 있습니다. 찬성하는 이유와 반대하는 이유를 각각 살펴보겠습니다.
#
# ### 찬성하는 이유
#
# 1. **유연한 근무 환경**: 재택근무는 직원들에게 유연한 근무 시간을 제공하여 개인의 생활과 업무를 조화롭게 할 수 있습니다.
#
# 2. **교통비 및 시간 절약**: 출퇴근 시간을 줄일 수 있어 직원들이 더 많은 시간을 가족이나 개인적인 일에 사용할 수 있습니다.
#
# 3. **생산성 향상**: 일부 연구에 따르면, 재택근무가 직원의 생산성을 높일 수 있다는 결과도 있습니다. 조용한 환경에서 집중할 수 있는 기회가 많아지기 때문입니다.
#
# 4. **비용 절감**: 기업 측면에서도 사무실 운영 비용(임대료, 관리비 등)을 줄일 수 있습니다.
#
# 5. **인재 확보**: 재택근무를 도입하면 지역에 구애받지 않고 다양한 인재를 채용할 수 있는 기회가 늘어납니다.
#
# ### 반대하는 이유
#
# 1. **소통의 어려움**: 대면 소통이 줄어들면서 팀워크와 협업이 저해될 수 있습니다. 비언어적 커뮤니케이션이 부족해질 수 있습니다.
#
# 2. **업무와 개인 생활의 경계 모호**: 재택근무는 업무와 개인 생활의 경계를 흐리게 만들어, 직원들이 과중한 업무에 시달릴 수 있습니다.
#
# 3. **관리의 어려움**: 관리자가 직원의 업무 진행 상황을 파악하기 어려워질 수 있으며, 이는 성과 평가에 영향을 미칠 수 있습니다.
#
# 4. **사회적 고립감**: 재택근무는 직원들이 사회적 고립감을 느낄 수 있으며, 이는 정신 건강에 부정적인 영향을 미칠 수 있습니다.
#
# 5. **기술적 문제**: 재택근무를 위해 필요한 기술적 인프라가 부족한 경우, 업무에 차질이 생길 수 있습니다.
#
# 결론적으로, 재택근무의 전면 도입은 장단점이 있으며, 기업의 특성과 직원들의 요구에 따라 신중하게 결정해야 할 문제입니다. 혼합형 근무 모델(하이브리드 모델)과 같은 대안도 고려해볼 수 있습니다.

# %%
# ── Zero-shot: 예시 없이 바로 질문 ────────────────────────────
zero_shot_prompt = ChatPromptTemplate.from_messages([
    ("human", "{question}")
])

# 체인 생성 및 실행
chain = zero_shot_prompt | llm | StrOutputParser()
result = chain.invoke({"question": "prompt engineering 분야에서 chain에 대해서 더 자세히 설명해 줘"})
# Prompt | LLM | OutputParser 구조

print("=== Zero-shot 결과 ===")
print(result)
# Out:
# === Zero-shot 결과 ===
# Prompt engineering 분야에서 "chain"은 여러 개의 프롬프트나 작업을 연결하여 복잡한 작업을 수행하는 방법을 의미합니다. 이는 주로 자연어 처리(NLP) 모델, 특히 대형 언어 모델(LLM)을 사용할 때 유용합니다. 체인 방식은 여러 단계의 프롬프트를 통해 모델의 출력을 점진적으로 개선하거나, 특정한 목표를 달성하기 위해 여러 단계를 거치는 과정을 포함합니다.
#
# ### Chain의 주요 개념
#
# 1. **단계적 접근**: 복잡한 질문이나 작업을 여러 개의 간단한 단계로 나누어 처리합니다. 각 단계는 이전 단계의 출력을 입력으로 사용하여 다음 단계를 수행합니다.
#
# 2. **모듈화**: 각 단계는 독립적으로 설계될 수 있으며, 필요에 따라 수정하거나 교체할 수 있습니다. 이를 통해 유연성과 재사용성을 높일 수 있습니다.
#
# 3. **상황에 맞는 프롬프트**: 각 단계에서 사용하는 프롬프트는 특정한 작업이나 질문에 맞게 조정됩니다. 예를 들어, 첫 번째 단계에서 정보를 수집하고, 두 번째 단계에서 그 정보를 분석하는 식으로 진행할 수 있습니다.
#
# 4. **피드백 루프**: 체인 내에서 각 단계의 출력을 평가하고, 필요에 따라 이전 단계로 돌아가 수정할 수 있는 피드백 루프를 포함할 수 있습니다. 이를 통해 결과의 품질을 높일 수 있습니다.
#
# ### 예시
#
# 예를 들어, "고양이에 대한 블로그 포스트 작성"이라는 작업을 수행한다고 가정해 보겠습니다. 이 작업을 체인으로 나누면 다음과 같은 단계가 있을 수 있습니다:
#
# 1. **정보 수집**: "고양이에 대한 주요 특징과 사실을 나열해 줘."
# 2. **구조화**: "다음 정보를 바탕으로 블로그 포스트의 개요를 만들어 줘."
# 3. **작성**: "이 개요를 바탕으로 블로그 포스트를 작성해 줘."
# 4. **편집**: "작성된 포스트를 검토하고, 문법 및 스타일을 수정해 줘."
#
# 이와 같이 각 단계가 서로 연결되어 있으며, 최종 목표인 블로그 포스트 작성에 도달하기 위해 체계적으로 진행됩니다.
#
# ### 활용 사례
#
# - **질문 응답 시스템**: 사용자의 질문에 대해 여러 단계를 거쳐 최종 답변을 제공하는 시스템.
# - **콘텐츠 생성**: 블로그, 기사, 스크립트 등을 작성할 때 단계별로 정보를 수집하고 정리하는 과정.
# - **데이터 분석**: 데이터 수집, 전처리, 분석, 시각화 등의 단계를 체계적으로 연결하여 결과를 도출하는 과정.
#
# 이처럼 chain은 복잡한 작업을 보다 효율적으로 수행할 수 있도록 도와주는 중요한 기법입니다.

# %% [markdown]
# ---
#
# ## 2. Few-shot Prompting
#
# 프롬프트 안에 **예시(shots)** 를 포함해서 원하는 출력 형식을 보여줍니다.
# LLM이 패턴을 학습해 같은 형식으로 답변합니다.
#
# ```
# 시스템: 예시1: Q→A, 예시2: Q→A  ← 패턴 학습
# 사용자: [새 질문]
# LLM:   [예시와 같은 형식의 답변]  ← 패턴 따라함
# ```

# %%
# ── Few-shot: 예시 2개를 포함해서 출력 형식을 유도 ────────────
# TODO: 아래 예시 2개(질문→답변 형식)를 참고해 같은 형식으로 답하도록 지시하는
#       시스템 프롬프트를 작성하세요 (✅ 찬성 근거 / ❌ 반대 근거 / 💡 결론 형식)

few_shot_prompt = ChatPromptTemplate.from_messages([
    ("system", 
    """ 
    아래 형식에 맞춰서 답변해

    질문 : 재택근무 전면 도입, 찬성해야 할까요?

    ✅ 찬성 근거

        생산성과 업무 집중도가 향상될 수 있다.

        출퇴근 시간이 줄어 직원 만족도와 워라밸이 높아질 수 있다.

        사무실 운영 비용을 절감할 수 있다.

    ❌ 반대 근거

        팀원 간 협업과 즉각적인 의사소통이 어려워질 수 있다.

        조직 문화와 소속감이 약해질 수 있다.

        직무에 따라 업무 효율과 성과 관리가 어려울 수 있다.

    💡 결론

        재택근무 전면 도입은 비용 절감과 직원 만족도 향상이라는 장점이 있지만, 
        협업과 조직 문화 유지에는 어려움이 있을 수 있습니다. 따라서 모든 직무에 
        일괄 적용하기보다는 직무 특성과 조직 상황을 고려한 하이브리드 근무 방식이
        현실적인 대안이 될 수 있습니다.    

    """),
    ("human", "질문: {question}")
])

# 체인 생성 및 실행
chain = few_shot_prompt | llm | StrOutputParser()
result = chain.invoke({"question": "내일 휴가를 쓸까?"})

print("=== Few-shot 결과 ===")
print(result)
# Out:
# === Few-shot 결과 ===
# ✅ 찬성 근거
#
# - 휴식을 통해 스트레스를 해소하고 재충전할 수 있다.
# - 개인적인 일이나 가족과의 시간을 가질 수 있는 기회가 된다.
# - 업무 효율성을 높이기 위해 필요한 휴식이 될 수 있다.
#
# ❌ 반대 근거
#
# - 휴가로 인해 업무에 차질이 생길 수 있다.
# - 동료에게 부담을 줄 수 있으며, 팀의 진행 상황에 영향을 미칠 수 있다.
# - 휴가 후 복귀 시 쌓인 업무로 인해 스트레스를 받을 수 있다.
#
# 💡 결론
#
# 내일 휴가를 쓰는 것은 개인의 재충전과 스트레스 해소에 도움이 될 수 있지만, 업무에 미치는 영향도 고려해야 합니다. 만약 긴급한 업무가 없다면 휴가는 긍정적인 선택이 될 수 있으며, 그렇지 않다면 적절한 시기를 찾아 휴가를 계획하는 것이 좋습니다.

# %% [markdown]
# ---
#
# ## 3. Chain-of-Thought (CoT) Prompting
#
# LLM에게 **단계별로 생각하도록** 유도합니다.
# 복잡한 추론, 계획, 분석이 필요한 질문에 효과적입니다.
#
# ```
# 기본:  질문 → 바로 답변 (shallow)
# CoT:  질문 → 단계1 → 단계2 → 단계3 → 결론 (deep)
# ```

# %%
# ── Chain-of-Thought: 단계별 사고 과정 명시 ───────────────────
# TODO: 4단계([1단계: 문제 파악]~[4단계: 최종 판단])로 생각하고
#       각 단계를 명시하도록 지시하는 시스템 프롬프트를 작성하세요
cot_prompt = ChatPromptTemplate.from_messages([
    ("system", 
     """
     질문에 답변하기 전에 반드시 4단계로 생각하고, 각 단계를 명시적으로 출력하세요.
     [1단계 : 문제 파악] 질문이 무엇인가?
     [2단계 : 이해관계자 분석] 누가 영향을 받는가?
     [3단계 : 장단점 분석] 적용했을 때 장점과 단점을 찾아서 
     [4단계 : 최종판단] 근거를 제시하고 결론을 내린다.
     
     """),
    ("human", "{question}")
])

# 체인 생성 및 실행
chain = cot_prompt | llm | StrOutputParser()
result = chain.invoke({"question": "내일 휴가를 쓸까?"})

print("=== Chain-of-Thought 결과 ===")
print(result)
# Out:
# === Chain-of-Thought 결과 ===
# [1단계 : 문제 파악]
# 질문은 "내일 휴가를 쓸까?"로, 이는 내일 하루를 휴가로 보내는 것이 좋을지에 대한 고민을 나타냅니다.
#
# [2단계 : 이해관계자 분석]
# 이해관계자는 본인(휴가를 쓰고자 하는 사람)과 직장 동료들(휴가로 인해 업무에 영향을 받을 수 있는 사람들), 상사(휴가 승인을 해야 할 경우) 등이 있습니다. 본인의 휴가는 개인적인 휴식과 재충전을 위한 것이지만, 동료와 상사에게는 업무의 연속성에 영향을 미칠 수 있습니다.
#
# [3단계 : 장단점 분석]
# 장점:
# - 휴식을 통해 스트레스를 해소하고 재충전할 수 있다.
# - 개인적인 일이나 가족과의 시간을 보낼 수 있다.
# - 업무 효율성을 높일 수 있는 기회가 된다.
#
# 단점:
# - 휴가로 인해 동료들에게 업무 부담이 증가할 수 있다.
# - 상사에게 휴가 승인을 받아야 하며, 이 과정에서 불편함이 있을 수 있다.
# - 휴가 후 업무에 복귀했을 때 쌓인 업무로 인해 스트레스를 받을 수 있다.
#
# [4단계 : 최종판단]
# 휴가를 쓰는 것은 개인의 재충전과 스트레스 해소에 긍정적인 영향을 미칠 수 있지만, 동료와 상사에게 미치는 영향도 고려해야 합니다. 만약 내일 휴가를 쓰는 것이 본인에게 필요한 휴식이라면, 동료들과 상사와의 소통을 통해 업무 조정을 잘 한다면 긍정적인 선택이 될 것입니다. 결론적으로, 내일 휴가를 쓰는 것이 좋다고 판단됩니다.

# %% [markdown]
# ---
#
# ## 4. 역할(Role) 프롬프트
#
# LLM에게 **특정 전문가 페르소나**를 부여합니다.
# 같은 질문이라도 역할에 따라 완전히 다른 관점으로 답변합니다.
#
# ```
# 역할 없음:  중립적·일반적 답변
# HR 전문가:  사람 중심의 조직 관점
# CFO:       비용·효율 중심의 재무 관점
# ```

# %%
# ── 역할 프롬프트: 같은 질문, 다른 역할 ──────────────────────
def make_role_chain(role_description: str):
    """역할 설명을 받아 전문가 체인을 생성한다"""
    prompt = ChatPromptTemplate.from_messages([
        ("system", role_description),
        ("human", "{question}")
    ])
    chain = prompt | llm | StrOutputParser()
    return chain

question = "재택근무 전면 도입, 찬성해야 할까요?"

# %%
hr_chain = make_role_chain(
    """
    객관적인 사실과 일반적인 관점으로만 답변하고 특정 직무의 편향은 적용하지 마세요."
    """)
print("=== HR 디렉터 관점 ===")
print(hr_chain.invoke({"question": question}))

# TODO: 10년 경력 CFO 역할을 설명하는 문자열을 작성하세요
#       (비용-효익 분석 중심, 수치 근거로 3~4문장으로 답하도록 지시)
# Out:
# === HR 디렉터 관점 ===
# 재택근무의 전면 도입에 대한 찬반 의견은 여러 가지 측면에서 고려될 수 있습니다.
#
# **찬성하는 이유:**
#
# 1. **유연성**: 재택근무는 직원들에게 유연한 근무 시간을 제공하여 개인의 생활과 업무를 조화롭게 할 수 있습니다.
# 2. **교통비 절감**: 출퇴근 시간이 줄어들어 교통비와 시간을 절약할 수 있습니다.
# 3. **생산성 향상**: 일부 연구에 따르면, 재택근무가 직원의 생산성을 높일 수 있다는 결과가 있습니다.
# 4. **업무 환경 개선**: 직원들이 자신에게 맞는 환경에서 일할 수 있어 업무 효율성이 증가할 수 있습니다.
#
# **반대하는 이유:**
#
# 1. **소통의 어려움**: 팀원 간의 즉각적인 소통이 어려워질 수 있으며, 협업이 저해될 수 있습니다.
# 2. **업무 집중도 저하**: 가정에서의 다양한 방해 요소로 인해 집중력이 떨어질 수 있습니다.
# 3. **직원 관리의 어려움**: 관리자가 직원의 업무 진행 상황을 파악하기 어려워질 수 있습니다.
# 4. **조직 문화 약화**: 사무실에서의 대면 소통이 줄어들어 조직 문화가 약화될 수 있습니다.
#
# 결론적으로, 재택근무의 전면 도입은 기업의 특성과 직원의 요구에 따라 다르게 평가될 수 있으며, 각 조직의 상황에 맞는 최적의 근무 형태를 찾아가는 것이 중요합니다.

# %%
cfo_chain = make_role_chain(
    """
    객관적인 사실과 일반적인 관점으로만 답변하고 특정 직무의 편향은 적용하지 마세요."
    """)
print("\n=== CFO 관점 ===")
print(cfo_chain.invoke({"question": question}))
# Out:
# === CFO 관점 ===
# 재택근무의 전면 도입에 대한 찬반 의견은 여러 가지 측면에서 고려될 수 있습니다.
#
# **찬성하는 이유:**
#
# 1. **유연한 근무 환경**: 재택근무는 직원들에게 유연한 근무 시간을 제공하여 개인의 생활과 업무의 균형을 맞출 수 있게 합니다.
#
# 2. **통근 시간 절약**: 출퇴근 시간을 줄일 수 있어 직원들이 더 많은 시간을 개인적인 활동이나 업무에 할애할 수 있습니다.
#
# 3. **비용 절감**: 기업은 사무실 운영 비용을 줄일 수 있으며, 직원들도 교통비와 식비 등의 비용을 절감할 수 있습니다.
#
# 4. **재능 확보**: 지리적 제약이 없으므로, 다양한 지역에서 인재를 채용할 수 있는 기회가 늘어납니다.
#
# **반대하는 이유:**
#
# 1. **소통의 어려움**: 대면 소통이 줄어들어 팀워크와 협업이 저해될 수 있으며, 의사소통의 효율성이 떨어질 수 있습니다.
#
# 2. **업무 집중도 저하**: 가정에서의 다양한 방해 요소로 인해 업무 집중도가 낮아질 수 있습니다.
#
# 3. **직원 관리의 어려움**: 관리자가 직원의 업무 진행 상황을 파악하기 어려워질 수 있으며, 성과 평가가 복잡해질 수 있습니다.
#
# 4. **조직 문화의 약화**: 사무실에서의 대면 활동이 줄어들면서 조직 문화가 약화될 수 있습니다.
#
# 결론적으로, 재택근무의 전면 도입은 장단점이 있으며, 각 기업의 상황과 직원들의 요구에 따라 신중하게 결정해야 할 문제입니다.

# %%
new_chain = make_role_chain(
    """
    입사한지 두달된 마냥 쉬는게 좋은 신입사원 입장
    """)
print("\n=== 신입사원 관점 ===")
print(new_chain.invoke({"question": question}))
# Out:
# === 신입사원 관점 ===
# 재택근무 전면 도입에 대한 찬반 의견은 여러 가지가 있습니다. 찬성하는 입장에서 고려할 수 있는 장점은 다음과 같습니다:
#
# 1. **유연한 근무 환경**: 재택근무는 직원들이 자신의 일정에 맞춰 일할 수 있는 유연성을 제공합니다. 이는 일과 삶의 균형을 맞추는 데 도움이 됩니다.
#
# 2. **교통비 및 시간 절약**: 출퇴근 시간을 줄일 수 있어, 직원들은 더 많은 시간을 개인적인 활동이나 가족과 함께 보낼 수 있습니다.
#
# 3. **생산성 향상**: 일부 연구에 따르면, 재택근무가 직원의 생산성을 높일 수 있다는 결과도 있습니다. 조용한 환경에서 일할 수 있어 집중력이 향상될 수 있습니다.
#
# 4. **비용 절감**: 기업 측면에서도 사무실 운영 비용을 줄일 수 있습니다. 임대료, 관리비, 전기세 등의 비용이 절감될 수 있습니다.
#
# 5. **인재 확보**: 재택근무를 도입하면 지역에 구애받지 않고 다양한 인재를 채용할 수 있는 기회가 늘어납니다.
#
# 하지만 반대하는 입장에서도 몇 가지 우려 사항이 있습니다:
#
# 1. **팀워크와 소통의 어려움**: 대면 소통이 줄어들면 팀워크와 협업이 어려워질 수 있습니다. 비즈니스의 일부는 관계 구축과 신뢰 형성이 중요합니다.
#
# 2. **업무 경계의 모호함**: 재택근무는 업무와 개인 생활의 경계가 모호해질 수 있어, 직원들이 과중한 업무에 시달릴 수 있습니다.
#
# 3. **기술적 문제**: 원활한 재택근무를 위해서는 안정적인 인터넷과 적절한 기술 지원이 필요합니다. 기술적 문제가 발생할 경우 업무에 지장이 생길 수 있습니다.
#
# 4. **직원 관리의 어려움**: 관리자가 직원의 업무 진행 상황을 파악하기 어려워질 수 있으며, 이는 성과 평가에 영향을 미칠 수 있습니다.
#
# 결론적으로, 재택근무의 전면 도입은 장단점이 있으며, 각 기업의 상황과 문화에 따라 다르게 적용될 수 있습니다. 따라서, 찬성 여부는 이러한 요소들을 종합적으로 고려하여 결정하는 것이 중요합니다.

# %% [markdown]
# ---
#
# ## 5. 구조화된 출력 (Structured Output)
#
# LLM의 출력을 **JSON 등 특정 형식으로 강제**합니다.
# 후처리(파싱, DB 저장, API 응답)가 필요할 때 사용합니다.
#
# ```
# 일반 출력: 자연어 문장 → 파싱 불가
# 구조화:   JSON/YAML → 자동 파싱 가능 → 시스템 연동 가능
# ```

# %%
# ── 구조화된 출력: JSON 형식 강제 ────────────────────────────
# TODO: topic·pros·cons·recommendation·confidence 필드를 가진 JSON으로만
#       답하도록(다른 텍스트 금지) 강제하는 시스템 프롬프트를 작성하세요
structured_prompt = ChatPromptTemplate.from_messages([
    ("system", 
     """
     반드시 아래 형식으로 답변하세요. 다른 텍스트는 절대로 포함하면 안됩니다.
     
     - 출력형식 : json
     
     "topic":"주제",
     "pros":["찬성근거1","찬성근거2","찬성근거3"],
     "cons":["반대근거1,"반대근거2"],
     "recommendation":"최종 결론",
     "confidence":"확신도(1~10)",

     """),
    ("human", "다음 주제를 분석해줘: {question}")
])

# 체인 생성 및 실행
chain = structured_prompt | llm | StrOutputParser()
raw_output = chain.invoke({"question": "재택근무 전면 도입"})

print("=== LLM 원본 출력 ===")
print(raw_output)

# JSON 파싱
print("\n=== 파싱 후 활용 ===")
try:
    data = json.loads(raw_output)
    print(f"주제     : {data['topic']}")
    print(f"확신도   : {data['confidence']}/10")
    print(f"권고사항 : {data['recommendation']}")
    print(f"찬성 근거: {', '.join(data['pros'])}")
except json.JSONDecodeError as e:
    print(f"파싱 실패: {e}")
    print("→ 팁: 모델이 JSON을 못 지키면 출력에서 JSON 부분만 추출하거나 재시도 로직을 추가하세요.")
# Out:
# === LLM 원본 출력 ===
# {
#   "topic": "재택근무 전면 도입",
#   "pros": [
#     "유연한 근무시간으로 직원의 워라밸 향상",
#     "사무실 유지비용 절감으로 기업 비용 절감",
#     "지리적 제약 없이 인재 채용 가능"
#   ],
#   "cons": [
#     "팀워크와 소통의 어려움으로 인한 생산성 저하",
#     "직원 관리 및 성과 평가의 어려움"
#   ],
#   "recommendation": "재택근무를 전면 도입하되, 팀 소통과 관리 방안을 강화해야 한다.",
#   "confidence": "8"
# }
#
# === 파싱 후 활용 ===
# 주제     : 재택근무 전면 도입
# 확신도   : 8/10
# 권고사항 : 재택근무를 전면 도입하되, 팀 소통과 관리 방안을 강화해야 한다.
# 찬성 근거: 유연한 근무시간으로 직원의 워라밸 향상, 사무실 유지비용 절감으로 기업 비용 절감, 지리적 제약 없이 인재 채용 가능

# %% [markdown]
# ---
#
# ## 6. 프롬프트 템플릿 (재사용 가능한 팩토리)
#
# **변수화된 프롬프트**를 만들어 다양한 도메인에 재사용합니다.
# 같은 구조의 프롬프트를 반복해서 만들 때 효율적입니다.
#
# ```python
# # 나쁜 예: 비슷한 프롬프트를 계속 복붙
# legal_prompt   = "당신은 변호사입니다... {question}"
# medical_prompt = "당신은 의사입니다... {question}"
#
# # 좋은 예: 팩토리 함수로 생성
# make_expert_chain(domain="법률", style="간결하게")
# make_expert_chain(domain="의료", style="쉽게 설명")
# ```

# %%
# ── 프롬프트 템플릿 팩토리 ────────────────────────────────────
def make_analyst_chain(domain: str, perspective: str, output_format: str):
    """
    재사용 가능한 분석 체인을 생성한다.

    Args:
        domain      : 전문 도메인 (예: '경영', '기술', '심리')
        perspective : 분석 관점 (예: '비용 중심', '사람 중심')
        output_format: 출력 형식 지시문
    """
    prompt = ChatPromptTemplate.from_messages([
        ("system", f"""당신은 {domain} 분야 전문 분석가입니다.
{perspective} 관점에서 분석하세요.

출력 형식:
{output_format}"""),
        ("human", "{question}")
    ])

    # 체인 생성
    chain = prompt | llm | StrOutputParser()
    return chain


# TODO: domain="경영", perspective="ROI와 생산성 중심"으로 채우고
#       output_format에 [핵심 지표]→[예상 효과]→[실행 권고] 형식을 지정하세요
biz_chain = make_analyst_chain(
    domain="경영",
    perspective="ROI와 생산성 중심",
    output_format="[핵심 지표]→[예상 효과]→[실행 권고]"
)

# TODO: domain="조직심리", perspective="구성원 동기·몰입 중심"으로 채우고
#       output_format에 [심리적 영향]→[리스크]→[권고사항] 형식을 지정하세요
psych_chain = make_analyst_chain(
    domain="조직심리",
    perspective="구성원 동기·몰입 중심",
    output_format="[심리적 영향]→[리스크]→[권고사항]"
)

question = "재택근무 전면 도입, 찬성해야 할까요?"

print("=== 경영 분석 관점 ===")
print(biz_chain.invoke({"question": question}))

print("\n=== 조직심리 관점 ===")
print(psych_chain.invoke({"question": question}))
# Out:
# === 경영 분석 관점 ===
# [핵심 지표]→[예상 효과]→[실행 권고]
#
# [생산성]→[재택근무 도입 후 직원들이 자율적으로 일할 수 있는 환경이 조성되어, 업무 집중도가 높아지고 생산성이 증가할 것으로 예상됨]→[재택근무를 전면 도입하기 전에 파일럿 프로그램을 운영하여 생산성 변화를 측정하고, 긍정적인 결과가 나타날 경우 전면 도입을 추진할 것을 권장]
#
# [ROI]→[재택근무로 인한 사무실 운영 비용 절감(임대료, 관리비 등)과 직원 이직률 감소로 인한 채용 비용 절감이 발생할 것으로 예상됨]→[재택근무의 비용 절감 효과를 분석하고, 이를 통해 ROI가 긍정적으로 나타날 경우 전면 도입을 고려할 것을 권장]
#
# [직원 만족도]→[재택근무가 직원의 워라밸을 개선하여 직무 만족도가 높아지고, 이는 결과적으로 기업의 성과에 긍정적인 영향을 미칠 것으로 예상됨]→[직원들의 의견을 수렴하고, 재택근무에 대한 만족도를 조사하여 정책 수립에 반영할 것을 권장]
#
# === 조직심리 관점 ===
# [심리적 영향]→재택근무는 구성원들에게 유연한 근무 환경을 제공하여 일과 삶의 균형을 개선할 수 있습니다. 이는 직원들의 동기와 몰입을 높이는 긍정적인 요소로 작용할 수 있습니다. 그러나, 사회적 상호작용의 감소로 인해 고립감을 느끼거나 팀워크가 약화될 수 있는 부정적인 영향도 존재합니다.
#
# [리스크]→재택근무가 전면 도입될 경우, 구성원 간의 소통 부족으로 인한 정보의 단절, 팀워크 저하, 그리고 직무 몰입의 감소가 발생할 수 있습니다. 또한, 자율성이 증가하면서 일부 직원들은 업무에 대한 책임감을 느끼지 못할 위험이 있습니다.
#
# [권고사항]→재택근무를 전면 도입하기 전에, 구성원들의 의견을 수렴하고, 정기적인 팀 미팅 및 소통 채널을 마련하여 상호작용을 촉진해야 합니다. 또한, 성과 기반의 평가 시스템을 도입하여 직원들이 자율성을 가지면서도 책임감을 느낄 수 있도록 지원하는 것이 중요합니다. 이를 통해 동기와 몰입을 유지할 수 있는 환경을 조성해야 합니다.

# %% [markdown]
# ---
#
# ## 7. 비교 실험: 같은 질문, 다른 기법
#
# 지금까지 배운 6가지 기법을 **같은 질문**에 적용해 결과를 비교합니다.
# 답변의 구조, 깊이, 형식이 얼마나 다른지 확인하세요.

# %%
# ── 비교 실험: 기법별 답변 길이 & 구조 비교 ──────────────────
QUESTION = "재택근무 전면 도입, 찬성해야 할까요?"

# 각 기법의 체인 목록
techniques = [
    ("Zero-shot",         zero_shot_prompt),
    ("Few-shot",          few_shot_prompt),
    ("Chain-of-Thought",  cot_prompt),
]

print(f"질문: {QUESTION}")
print("=" * 60)

results = {}
for name, prompt in techniques:
    chain = prompt | llm | StrOutputParser()
    answer = chain.invoke({"question": QUESTION})
    results[name] = answer

# 결과 요약 출력
print(f"\n{'기법':<20} {'글자수':>8} {'줄 수':>6}")
print("-" * 38)
for name, answer in results.items():
    print(f"{name:<20} {len(answer):>8,} {len(answer.splitlines()):>6}")

# %%
# ── 답변 전체 출력 ────────────────────────────────────────────
for name, answer in results.items():
    print(f"\n{'='*60}")
    print(f"[{name}]")
    print('='*60)
    # 처음 400자만 출력 (너무 길면 ...으로 줄임)
    preview = answer[:400]
    print(preview)
    if len(answer) > 400:
        print(f"\n... (총 {len(answer):,}자 중 400자 미리보기)")

# %% [markdown]
# ---
#
# ## 핵심 정리
#
# ```python
# # 프롬프트 엔지니어링 선택 가이드
#
# # 1. Zero-shot: 빠른 테스트, 일반 질문
# chain = ChatPromptTemplate.from_messages([("human", "{q}")]) | llm | StrOutputParser()
#
# # 2. Few-shot: 특정 형식 유도, 스타일 일관성
# #    → 시스템 프롬프트에 예시 2~3개 포함
#
# # 3. Chain-of-Thought: 복잡한 추론, 다단계 분석
# #    → "단계별로 생각하세요" 지시문 추가
#
# # 4. 역할 프롬프트: 전문 도메인, 특정 관점 필요 시
# #    → 구체적일수록 좋음 ("전문가" < "10년 경력 변호사")
#
# # 5. 구조화 출력: 파싱·연동이 필요한 경우
# #    → JSON 형식 + "다른 텍스트 포함 금지" 명시
#
# # 6. 팩토리 패턴: 동일 구조 반복 시
# def make_chain(domain, style):
#     prompt = ChatPromptTemplate.from_messages([...])
#     return prompt | llm | StrOutputParser()
# ```
#
# | 기법 | 최적 상황 | 주의사항 |
# |---|---|---|
# | Zero-shot | 범용 질문, 빠른 프로토타입 | 형식 보장 없음 |
# | Few-shot | 특정 형식·스타일 필요 | 예시가 너무 많으면 토큰 낭비 |
# | CoT | 복잡한 추론·판단 | 응답이 길어짐 |
# | 역할 | 전문 도메인 | 구체적일수록 효과적 |
# | 구조화 출력 | API 연동, 파싱 필요 | 100% 보장 안 됨 (검증 로직 필요) |
# | 팩토리 | 반복 사용 패턴 | 과도한 추상화 주의 |
